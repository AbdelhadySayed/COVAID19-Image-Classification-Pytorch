# %%
# %run main.py --batch-size 32 --epochs 20 --learning-rate 0.01
# Out:
# -----------------------------------------------------------
#  Epoch 1: train loss 0.016, test_loss 0.021, in 702.1 sec
#
#   train Accuracy 77%, test Accuracy 64%
#
# -----------------------------------------------------------
#  Epoch 2: train loss 0.012, test_loss 0.018, in 696.8 sec
#
#   train Accuracy 82%, test Accuracy 74%
#
# -----------------------------------------------------------
#  Epoch 3: train loss 0.012, test_loss 0.015, in 699.5 sec
#
#   train Accuracy 83%, test Accuracy 80%
#
# -----------------------------------------------------------
#  Epoch 4: train loss 0.012, test_loss 0.015, in 674.3 sec
#
#   train Accuracy 83%, test Accuracy 76%
#
# -----------------------------------------------------------
#  Epoch 5: train loss 0.011, test_loss 0.015, in 636.1 sec
#
#   train Accuracy 83%, test Accuracy 78%
#
# -----------------------------------------------------------
#  Epoch 6: train loss 0.011, test_loss 0.016, in 706.8 sec
#
# ...
